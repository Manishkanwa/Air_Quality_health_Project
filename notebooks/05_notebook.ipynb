# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import streamlit as st
import folium 
import streamlit_folium
# Out:
# 2025-06-10 16:50:24.228 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = pd.read_excel("D:\\Air_Quality_health_Project\\data\\clean_data\\AQI_Cases_data.xlsx")

# %%
df.head()
# Out:
#    Location_id  Sensor_id           State             Area Sensor_name  \
# 0         5628      14969  Andhra Pradesh  GVM Corporation    co µg/m³
# 1         5628      14969  Andhra Pradesh  GVM Corporation    co µg/m³
# 2         5628      14969  Andhra Pradesh  GVM Corporation    co µg/m³
# 3         5628      14969  Andhra Pradesh  GVM Corporation    co µg/m³
# 4         5628      14969  Andhra Pradesh  GVM Corporation    co µg/m³
#
#     Latitude  Longitude  Population_lakhs     Month  Asthama_Cases  \
# 0  17.722682  83.308197               540   January           6400
# 1  17.722682  83.308197               540  February           6400
# 2  17.722682  83.308197               540     March           7200
# 3  17.722682  83.308197               540     April           5600
# 4  17.722682  83.308197               540       May           4800
#
#    Bronchitis_Cases  Heart_attacks  COPD_Cases  Neumonia_Cases DateTimeFrom  \
# ...

# %%
lat =list(dict(df)['Latitude'])
long = list(dict(df)['Longitude'])
for i in range(len(lat)):
    print(lat[i], long[i])
# Out:
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# 17.722682 83.308197
# ...
